# %%
import pandas as pd
import numpy as np

# %%
action_space = pd.read_csv("../Discrete Data/non_discritised_data.csv")
action_space
# Out:
#        vent_rate_set  peep  fio2  ECMO Pump Flow  ECMO Sweep Gas Flow  \
# 0               10.0  16.0  0.55        5.077500                 9.50
# 1               10.0  16.0  1.00        5.417500                10.00
# 2               10.0  16.0  1.00        5.652500                10.00
# 3               10.0  16.0  1.00        6.225000                10.00
# 4               10.0  16.0  0.60        6.405000                10.00
# ...              ...   ...   ...             ...                  ...
# 15187           10.0  10.0  0.40        5.942500                10.00
# 15188           10.0  10.0  0.40        5.920000                10.00
# 15189           10.0  10.0  0.40        5.907500                10.25
# 15190           10.0  10.0  0.40        6.202500                11.00
# 15191           10.0  10.0  0.40        4.113333                11.00
#
#                csn
# 0         43640203
# 1         43640203
# 2         43640203
# 3         43640203
# 4         43640203
# ...            ...
# 15187  70840791325
# 15188  70840791325
# 15189  70840791325
# 15190  70840791325
# 15191  70840791325
#
# [15192 rows x 6 columns]

# %%
merge_data = pd.read_csv("../Discrete Data/ECMO_data_clustered.csv")
merge_data
# Out:
#        temperature  map_line  map_cuff     pulse  unassisted_resp_rate  \
# 0         1.654985  1.543293  0.712217  1.037490             -0.277493
# 1         0.179388  0.036551  0.685907 -0.148586             -0.277493
# 2        -1.182702  0.325409  0.685907 -0.125951             -0.277493
# 3        -0.501657 -0.420155 -0.300701  1.405686             -0.312486
# 4         1.314463 -0.100070  0.093942  3.125949             -0.067534
# ...            ...       ...       ...       ...                   ...
# 15187    -0.501657 -0.724626 -0.234927 -0.495657              0.632326
# 15188    -1.182702 -1.524839 -0.234927 -0.359847              0.562340
# 15189    -0.501657 -1.408711 -0.234927 -0.300116              0.637325
# 15190    -0.643542 -0.603619 -0.234927  0.359444             -0.090863
# 15191    -1.069195 -2.906670 -0.234927 -3.855703             -0.067534
#
#        end_tidal_co2  o2_flow_rate  base_excess  bicarb_(hco3)  \
# 0           1.443907     -0.794470    -0.319874      -0.824496
# 1           1.223377     -0.794470    -0.319874      -0.880290
# 2           1.100080     -0.794470    -0.319874      -0.746384
# 3           0.691097     -0.794470    -0.319874      -1.023762
# 4           0.817400     -0.794470    -0.319874      -0.387706
# ...              ...           ...          ...            ...
# 15187      -1.483133      1.449991    -0.161775      -0.827684
# 15188      -1.483133      1.449991    -0.161775      -0.827684
# 15189      -1.483133      1.449991    -0.161775      -0.827684
# 15190      -1.483133      1.449991    -0.161775      -0.827684
# 15191      -1.483133      1.449991    -0.161775      -0.827684
#
#        blood_urea_nitrogen_(bun)  ...  erythrocyte_sedimentation_rate_(esr)  \
# 0                       0.070542  ...                              1.634933
# 1                       0.051429  ...                              1.634933
# 2                       0.032315  ...                              1.634933
# 3                       0.032315  ...                              1.634933
# 4                       0.032315  ...                              1.634933
# ...                          ...  ...                                   ...
# 15187                  -0.655770  ...                             -0.428030
# 15188                  -0.770451  ...                             -0.428030
# 15189                  -0.770451  ...                             -0.428030
# 15190                  -0.770451  ...                             -0.428030
# 15191                  -0.770451  ...                             -0.428030
#
#        gcs_total_score  best_map     pf_sp     pf_pa      spo2  \
# 0            -1.598843  1.475408  1.028444 -1.108899 -0.454683
# 1            -1.598843 -0.011264 -1.524705 -1.093262 -0.158852
# 2            -1.598843  0.273745 -1.533378 -1.065115 -0.333475
# 3            -0.534057 -0.461888 -1.533889 -1.087007 -0.343746
# 4             0.530729  0.115835 -0.819034 -0.562856  0.858066
# ...                ...       ...       ...       ...       ...
# 15187         0.057491 -0.762304 -0.901044 -0.058841 -1.853716
# 15188         0.057491 -1.551858 -0.901044 -0.058841 -1.987251
# 15189         0.057491 -1.437276 -0.901044 -0.058841 -2.098530
# 15190         0.057491 -0.642908 -0.901044 -0.058841 -3.641028
# 15191         0.057491 -2.021739 -0.901044 -0.058841 -8.366104
#
#        partial_pressure_of_oxygen_(pao2)  rass_score   CAM_ICU          csn
# 0                              -0.687484   -1.002158  1.311655     43640203
# 1                              -0.640286   -0.579654  1.311655     43640203
# 2                              -0.555330   -0.438819  1.311655     43640203
# 3                              -0.621407   -0.016316 -0.279635     43640203
# 4                              -0.064474    1.673699 -0.810065     43640203
# ...                                  ...         ...       ...          ...
# 15187                          -0.028993    0.124519 -0.810065  70840791325
# 15188                          -0.028993    0.124519 -0.810065  70840791325
# 15189                          -0.028993    0.124519 -0.810065  70840791325
# 15190                          -0.028993    0.124519 -0.810065  70840791325
# 15191                          -0.028993    0.124519 -0.810065  70840791325
#
# [15192 rows x 43 columns]

# %%
con_data = pd.concat([merge_data,action_space],axis=1)
con_data.rename(columns={"ECMO Pump Flow": "flow","ECMO Sweep Gas Flow": "sweep"},inplace=True)
con_data
# con_data.to_csv("before_reward.csv",index=False)
# Out:
#        temperature  map_line  map_cuff     pulse  unassisted_resp_rate  \
# 0         1.654985  1.543293  0.712217  1.037490             -0.277493
# 1         0.179388  0.036551  0.685907 -0.148586             -0.277493
# 2        -1.182702  0.325409  0.685907 -0.125951             -0.277493
# 3        -0.501657 -0.420155 -0.300701  1.405686             -0.312486
# 4         1.314463 -0.100070  0.093942  3.125949             -0.067534
# ...            ...       ...       ...       ...                   ...
# 15187    -0.501657 -0.724626 -0.234927 -0.495657              0.632326
# 15188    -1.182702 -1.524839 -0.234927 -0.359847              0.562340
# 15189    -0.501657 -1.408711 -0.234927 -0.300116              0.637325
# 15190    -0.643542 -0.603619 -0.234927  0.359444             -0.090863
# 15191    -1.069195 -2.906670 -0.234927 -3.855703             -0.067534
#
#        end_tidal_co2  o2_flow_rate  base_excess  bicarb_(hco3)  \
# 0           1.443907     -0.794470    -0.319874      -0.824496
# 1           1.223377     -0.794470    -0.319874      -0.880290
# 2           1.100080     -0.794470    -0.319874      -0.746384
# 3           0.691097     -0.794470    -0.319874      -1.023762
# 4           0.817400     -0.794470    -0.319874      -0.387706
# ...              ...           ...          ...            ...
# 15187      -1.483133      1.449991    -0.161775      -0.827684
# 15188      -1.483133      1.449991    -0.161775      -0.827684
# 15189      -1.483133      1.449991    -0.161775      -0.827684
# 15190      -1.483133      1.449991    -0.161775      -0.827684
# 15191      -1.483133      1.449991    -0.161775      -0.827684
#
#        blood_urea_nitrogen_(bun)  ...  partial_pressure_of_oxygen_(pao2)  \
# 0                       0.070542  ...                          -0.687484
# 1                       0.051429  ...                          -0.640286
# 2                       0.032315  ...                          -0.555330
# 3                       0.032315  ...                          -0.621407
# 4                       0.032315  ...                          -0.064474
# ...                          ...  ...                                ...
# 15187                  -0.655770  ...                          -0.028993
# 15188                  -0.770451  ...                          -0.028993
# 15189                  -0.770451  ...                          -0.028993
# 15190                  -0.770451  ...                          -0.028993
# 15191                  -0.770451  ...                          -0.028993
#
#        rass_score   CAM_ICU          csn  vent_rate_set  peep  fio2      flow  \
# 0       -1.002158  1.311655     43640203           10.0  16.0  0.55  5.077500
# 1       -0.579654  1.311655     43640203           10.0  16.0  1.00  5.417500
# 2       -0.438819  1.311655     43640203           10.0  16.0  1.00  5.652500
# 3       -0.016316 -0.279635     43640203           10.0  16.0  1.00  6.225000
# 4        1.673699 -0.810065     43640203           10.0  16.0  0.60  6.405000
# ...           ...       ...          ...            ...   ...   ...       ...
# 15187    0.124519 -0.810065  70840791325           10.0  10.0  0.40  5.942500
# 15188    0.124519 -0.810065  70840791325           10.0  10.0  0.40  5.920000
# 15189    0.124519 -0.810065  70840791325           10.0  10.0  0.40  5.907500
# 15190    0.124519 -0.810065  70840791325           10.0  10.0  0.40  6.202500
# 15191    0.124519 -0.810065  70840791325           10.0  10.0  0.40  4.113333
#
#        sweep          csn
# 0       9.50     43640203
# 1      10.00     43640203
# 2      10.00     43640203
# 3      10.00     43640203
# 4      10.00     43640203
# ...      ...          ...
# 15187  10.00  70840791325
# 15188  10.00  70840791325
# 15189  10.25  70840791325
# 15190  11.00  70840791325
# 15191  11.00  70840791325
#
# [15192 rows x 49 columns]

# %%
sofa_scores = pd.read_csv("../Discrete Data/data_for_RL.csv")
sofa_scores.rename(columns={"short_term_reward": "sofa_sigma"},inplace=True)
sofa_scores['long_term_reward'] = sofa_scores['long_term_reward'].replace(10, 0)
sofa_scores['long_term_reward'] = sofa_scores['long_term_reward'].replace(-10, -1)
sofa_scores['reward'] = sofa_scores.groupby('csn')['sofa_sigma'].diff().fillna(0)
sofa_scores['reward'] = -sofa_scores['reward']/16
sofa_scores['long_term_fraction'] = sofa_scores['long_term_reward'] / sofa_scores.groupby('csn')['csn'].transform('count')
sofa_scores['cum_long_term'] = sofa_scores.groupby('csn')['long_term_fraction'].cumsum()
sofa_scores['reward'] = sofa_scores['reward']+sofa_scores['cum_long_term']

sofa_scores
# Out:
#                csn  action  sofa_sigma  long_term_reward  mortality_flag  \
# 0         43640203    1419    9.000000                 0             0.0
# 1         43640203    1924    8.500000                 0             0.0
# 2         43640203    1924    8.000000                 0             0.0
# 3         43640203    1925   11.000000                 0             0.0
# 4         43640203    1925   10.000000                 0             0.0
# ...            ...     ...         ...               ...             ...
# 15187  70840791325     724    9.533193                -1             1.0
# 15188  70840791325     724    8.533193                -1             1.0
# 15189  70840791325     724    7.283193                -1             1.0
# 15190  70840791325     725    4.533193                -1             1.0
# 15191  70840791325     723    5.033193                -1             1.0
#
#          reward  long_term_fraction  cum_long_term
# 0      0.000000            0.000000       0.000000
# 1      0.031250            0.000000       0.000000
# 2      0.031250            0.000000       0.000000
# 3     -0.187500            0.000000       0.000000
# 4      0.062500            0.000000       0.000000
# ...         ...                 ...            ...
# 15187 -0.954545           -0.011364      -0.954545
# 15188 -0.903409           -0.011364      -0.965909
# 15189 -0.899148           -0.011364      -0.977273
# 15190 -0.816761           -0.011364      -0.988636
# 15191 -1.031250           -0.011364      -1.000000
#
# [15192 rows x 8 columns]

# %%
con_data = con_data.loc[:,~con_data.columns.duplicated()]

# %%
# Function to determine the bin index for a value based on given ranges
def get_bin_index(value, ranges):
    for i, (low, high) in enumerate(ranges):
        if low < value <= high:
            return i
    return len(ranges) - 1  # If the value doesn't fall into any bin, return the last bin

# Add a new column for the result
con_data['bin_change_penalty'] = 0.0

# Define ranges for each setting
fio2_ranges = [(0, 0.4), (0.4, 0.5), (0.5, 0.6), (0.6, float('inf'))]
peep_ranges = [(0, 7), (7, 9), (9, 11), (11, 13), (13, float('inf'))]
vent_rate_set_ranges = [(0, 15), (15, 18), (18, 21), (21, float('inf'))]
sweep_ranges = [(0, 2.5), (2.5, 5), (5, 7.5), (7.5, 10), (10, float('inf'))]
flow_ranges = [(0, 3), (3, 4), (4, 5), (5, 6), (6, float('inf'))]

# Iterate over each csn group
for csn, group in con_data.groupby('csn'):
    # group = group.sort_values('timestamp')
    previous_row = None
    
    for index, row in group.iterrows():
        bin_change = 0  # Initialize the bin change for this row
        
        if previous_row is not None:
            # Check the difference in bins for each action
            fio2_diff = abs(get_bin_index(row['fio2'], fio2_ranges) - get_bin_index(previous_row['fio2'], fio2_ranges))
            peep_diff = abs(get_bin_index(row['peep'], peep_ranges) - get_bin_index(previous_row['peep'], peep_ranges))
            vent_rate_set_diff = abs(get_bin_index(row['vent_rate_set'], vent_rate_set_ranges) - get_bin_index(previous_row['vent_rate_set'], vent_rate_set_ranges))
            sweep_diff = abs(get_bin_index(row['sweep'], sweep_ranges) - get_bin_index(previous_row['sweep'], sweep_ranges))
            flow_diff = abs(get_bin_index(row['flow'], flow_ranges) - get_bin_index(previous_row['flow'], flow_ranges))
            
            # Accumulate -0.5 for each setting that exceeds one bin
            if fio2_diff > 1:
                bin_change += -0.5
            if peep_diff > 1:
                bin_change += -0.5
            if vent_rate_set_diff > 1:
                bin_change += -0.5
            if sweep_diff > 1:
                bin_change += -0.5
            if flow_diff > 1:
                bin_change += -0.5

            # Apply additional penalties based on specific conditions
            if row['fio2'] < 0.21 or row['fio2'] > 0.8:
                bin_change += -0.5
            if row['peep'] < 5 or row['peep'] > 20:
                bin_change += -0.5
            if row['vent_rate_set'] > 20:
                bin_change += -0.5
            if row['sweep'] >= 10:
                bin_change += -1
            if row['flow'] < 0.5 or row['flow'] >= 6:
                bin_change += -1
                
            con_data.at[index, 'bin_change_penalty'] = bin_change
        
        previous_row = row

# %%
con_data["reward"]=sofa_scores['reward']+con_data["bin_change_penalty"]
con_data.drop(columns="bin_change_penalty",inplace=True)

# %%
train_csn = pd.read_csv("../Discrete Data/ECMO_data_clustered_train.csv").csn.unique()
test_csn = pd.read_csv("../Discrete Data/ECMO_data_clustered_test.csv").csn.unique()

# %%
train_data = con_data[con_data['csn'].isin(train_csn)]
test_data = con_data[con_data['csn'].isin(test_csn)]

train_data.to_csv("train_data_continuous.csv",index=False)
test_data.to_csv("test_data_continuous.csv",index=False)

# %%
test_csn
# Out:
# array([ 4510511039,  6648317299, 10017307254, 12256550300, 17249721021,
#        19073406214, 38450329331, 42989860004, 43917519266, 46056470115,
#        46429729018, 53476486236, 55395459196, 55511607117, 55953247177,
#        56831407291, 57284130211, 62369850199, 63121461075, 64778739353,
#        64843720260, 64908640003, 65075060016, 65371760142, 66303050184,
#        66322050188, 66795550261, 66926880266, 67763261127, 67843131173,
#        67872761027, 68463091091, 68545791099, 68845081130, 69567811194,
#        69649561202, 70454151283])

# %%
test_data.csn.unique()
# Out:
# array([ 4510511039,  6648317299, 10017307254, 12256550300, 17249721021,
#        19073406214, 38450329331, 42989860004, 43917519266, 46056470115,
#        46429729018, 53476486236, 55395459196, 55511607117, 55953247177,
#        56831407291, 57284130211, 62369850199, 63121461075, 64778739353,
#        64843720260, 64908640003, 65075060016, 65371760142, 66303050184,
#        66322050188, 66795550261, 66926880266, 67763261127, 67843131173,
#        67872761027, 68463091091, 68545791099, 68845081130, 69567811194,
#        69649561202, 70454151283])

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

data = pd.read_csv("train_data_continuous_no_R_for_Survival.csv")
unique_csn = data['csn'].unique()
# First split: 80% train, 20% temp (validation + test)
train_csn, val_csn = train_test_split(unique_csn, test_size=0.2, random_state=3)

# %%
train_csn
# Out:
# array([43323090183, 66418670200, 60879489278, 70225691258, 68321591079,
#        63869689272, 19657017003, 15738357227, 55128050029, 53243526208,
#        19939811206, 67682541003, 65390550048, 52902477332, 45457761150,
#        66144110163, 70666401306, 44991746336, 62405229244, 17966029235,
#        53393046226, 65264380035, 10057670084, 12801159220, 65610930075,
#        69626971200, 12128379018, 67944491035, 12156649330, 68780921116,
#        68797341117, 69487791185, 65209900029, 53045406183, 69888941224,
#        11598700132, 67796811017, 69356011171, 68909051127, 48994390085,
#        66713900239, 67779421014, 67546400366, 56063101211, 64939920143,
#        52545546124, 45787461252, 69372091173, 69567531194, 53467166235,
#        68941281131, 56258940008, 68093021054, 42008659061, 66614490225,
#        14719067105, 54705307026, 63433549223, 68862911124, 65816090128,
#        43946031211, 64309929313, 15668590152, 65706900107, 63152719298,
#        65189640027,  2178911314, 69900791287, 53029789123, 66724300239,
#        61391379093, 66713901041, 55005397058, 67958411160, 58928481104,
#        16251981187, 67152710303, 60780209038, 70341401291, 54594307011,
#        38889741014, 63917349279, 70293951265, 53216836213, 65968410147,
#        19085650202, 48783979065, 53096266192, 64084909296, 44640859224,
#        52461796114, 68192231065, 11197349249, 57642960169, 68349741082,
#        20717069126, 70840791325, 39299217144, 66385050238, 67620281055,
#        66803750251, 61200959078, 65682400100, 68989721134, 56074260192,
#         2207761225, 60845329119, 64723420073, 32313439276, 65910640133,
#        68177151063, 69860091222, 67436910331, 19330760302,    43640203,
#        69241991159, 67307200314])

# %%
data = pd.read_csv("train_data_continuous_Pos_for_Survival.csv")
# Split the clustered data
train_cluster = data[data['csn'].isin(train_csn)]
val_cluster = data[data['csn'].isin(val_csn)]

# %%
train_cluster.to_csv("train_data_continuous_Pos_for_Survival.csv")
val_cluster.to_csv("val_data_continuous_Pos_for_Survival.csv")

# %%
# Out:
#        temperature  map_line  map_cuff     pulse  unassisted_resp_rate  \
# 91       -1.523225 -0.456774  0.949002  0.266892              0.025780
# 92       -1.579979 -0.328814  0.949002  0.994483              0.256151
# 93       -1.750240 -0.853441  0.949002  1.013345              0.212410
# 94       -1.523225 -0.002483  0.949002  0.790768             -0.434961
# 95       -0.842180  1.504259  0.949002  0.018122             -0.650751
# ...            ...       ...       ...       ...                   ...
# 11503     0.236142  0.821150  0.159716  0.387109              0.842284
# 11504     0.179388  1.207594  0.159716  0.153214              1.174718
# 11505    -0.331396  1.430092  0.159716  0.593340              1.174718
# 11506     0.236142  1.599894  0.159716  0.590825              0.457361
# 11507     0.746925  1.168560  0.159716  0.439925              0.632326
#
#        end_tidal_co2  o2_flow_rate  base_excess  bicarb_(hco3)  \
# 91          1.097073     -0.960726     2.745815       1.467855
# 92          1.097073     -0.960726     2.745815       1.467855
# 93          1.097073     -0.960726     2.745815       1.467855
# 94          1.097073     -0.960726     2.745815       1.467855
# 95          1.160655     -0.960726     2.745815       1.467855
# ...              ...           ...          ...            ...
# 11503      -1.483133     -0.711341     0.102010       0.893970
# 11504      -1.483133     -0.711341     0.102010       0.893970
# 11505      -1.483133     -0.711341     0.102010       0.893970
# 11506      -1.483133     -0.711341     0.102010       0.893970
# 11507      -1.483133     -0.711341     0.102010       0.893970
#
#        blood_urea_nitrogen_(bun)  ...  partial_pressure_of_oxygen_(pao2)  \
# 91                     -0.617543  ...                          -0.536451
# 92                     -0.617543  ...                          -0.536451
# 93                     -0.617543  ...                          -0.536451
# 94                     -0.617543  ...                          -0.536451
# 95                     -0.617543  ...                          -0.536451
# ...                          ...  ...                                ...
# 11503                  -1.305628  ...                           1.219302
# 11504                  -1.305628  ...                           1.219302
# 11505                  -1.305628  ...                           1.219302
# 11506                  -1.305628  ...                           1.219302
# 11507                  -1.305628  ...                           1.219302
#
#        rass_score   CAM_ICU          csn  vent_rate_set  peep  fio2    flow  \
# 91       1.251195 -0.810065   7270121193           10.0  10.0   0.4  3.5000
# 92      -0.157150 -0.810065   7270121193           10.0  10.0   0.3  3.6675
# 93      -0.438819 -0.810065   7270121193           10.0  10.0   0.3  3.5900
# 94      -0.157150 -0.810065   7270121193           10.0  10.0   0.3  3.5525
# 95       0.969526 -0.810065   7270121193           10.0  10.0   0.3  3.5650
# ...           ...       ...          ...            ...   ...   ...     ...
# 11503    1.251195 -0.810065  70201931257           18.0   6.0   0.4  2.6250
# 11504    1.110361 -0.810065  70201931257           18.0   6.0   0.4  2.6000
# 11505    0.687857 -0.810065  70201931257           18.0   6.0   0.4  2.6000
# 11506    1.251195 -0.810065  70201931257           18.0   6.0   0.4  2.6000
# 11507    1.251195 -0.810065  70201931257           18.0   6.0   0.4  2.5000
#
#        sweep        reward
# 91     1.875 -2.604167e-03
# 92     1.500 -1.821460e-17
# 93     1.500  7.812500e-03
# 94     1.500 -1.041667e-02
# 95     1.500 -1.302083e-02
# ...      ...           ...
# 11503  0.000  0.000000e+00
# 11504  0.000  0.000000e+00
# 11505  0.000  0.000000e+00
# 11506  0.000  0.000000e+00
# 11507  0.000  0.000000e+00
#
# [2978 rows x 49 columns]

# %%
val_cluster
# Out:
#        temperature  map_line  map_cuff     pulse  unassisted_resp_rate  \
# 91       -1.523225 -0.456774  0.949002  0.266892              0.025780
# 92       -1.579979 -0.328814  0.949002  0.994483              0.256151
# 93       -1.750240 -0.853441  0.949002  1.013345              0.212410
# 94       -1.523225 -0.002483  0.949002  0.790768             -0.434961
# 95       -0.842180  1.504259  0.949002  0.018122             -0.650751
# ...            ...       ...       ...       ...                   ...
# 11503     0.236142  0.821150  0.159716  0.387109              0.842284
# 11504     0.179388  1.207594  0.159716  0.153214              1.174718
# 11505    -0.331396  1.430092  0.159716  0.593340              1.174718
# 11506     0.236142  1.599894  0.159716  0.590825              0.457361
# 11507     0.746925  1.168560  0.159716  0.439925              0.632326
#
#        end_tidal_co2  o2_flow_rate  base_excess  bicarb_(hco3)  \
# 91          1.097073     -0.960726     2.745815       1.467855
# 92          1.097073     -0.960726     2.745815       1.467855
# 93          1.097073     -0.960726     2.745815       1.467855
# 94          1.097073     -0.960726     2.745815       1.467855
# 95          1.160655     -0.960726     2.745815       1.467855
# ...              ...           ...          ...            ...
# 11503      -1.483133     -0.711341     0.102010       0.893970
# 11504      -1.483133     -0.711341     0.102010       0.893970
# 11505      -1.483133     -0.711341     0.102010       0.893970
# 11506      -1.483133     -0.711341     0.102010       0.893970
# 11507      -1.483133     -0.711341     0.102010       0.893970
#
#        blood_urea_nitrogen_(bun)  ...  partial_pressure_of_oxygen_(pao2)  \
# 91                     -0.617543  ...                          -0.536451
# 92                     -0.617543  ...                          -0.536451
# 93                     -0.617543  ...                          -0.536451
# 94                     -0.617543  ...                          -0.536451
# 95                     -0.617543  ...                          -0.536451
# ...                          ...  ...                                ...
# 11503                  -1.305628  ...                           1.219302
# 11504                  -1.305628  ...                           1.219302
# 11505                  -1.305628  ...                           1.219302
# 11506                  -1.305628  ...                           1.219302
# 11507                  -1.305628  ...                           1.219302
#
#        rass_score   CAM_ICU          csn  vent_rate_set  peep  fio2    flow  \
# 91       1.251195 -0.810065   7270121193           10.0  10.0   0.4  3.5000
# 92      -0.157150 -0.810065   7270121193           10.0  10.0   0.3  3.6675
# 93      -0.438819 -0.810065   7270121193           10.0  10.0   0.3  3.5900
# 94      -0.157150 -0.810065   7270121193           10.0  10.0   0.3  3.5525
# 95       0.969526 -0.810065   7270121193           10.0  10.0   0.3  3.5650
# ...           ...       ...          ...            ...   ...   ...     ...
# 11503    1.251195 -0.810065  70201931257           18.0   6.0   0.4  2.6250
# 11504    1.110361 -0.810065  70201931257           18.0   6.0   0.4  2.6000
# 11505    0.687857 -0.810065  70201931257           18.0   6.0   0.4  2.6000
# 11506    1.251195 -0.810065  70201931257           18.0   6.0   0.4  2.6000
# 11507    1.251195 -0.810065  70201931257           18.0   6.0   0.4  2.5000
#
#        sweep        reward
# 91     1.875 -2.604167e-03
# 92     1.500 -1.821460e-17
# 93     1.500  7.812500e-03
# 94     1.500 -1.041667e-02
# 95     1.500 -1.302083e-02
# ...      ...           ...
# 11503  0.000  9.655172e-01
# 11504  0.000  9.741379e-01
# 11505  0.000  9.827586e-01
# 11506  0.000  9.913793e-01
# 11507  0.000  1.000000e+00
#
# [2978 rows x 49 columns]
